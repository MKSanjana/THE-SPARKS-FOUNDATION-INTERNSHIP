# %% [markdown]
# # THE SPARKS FOUNDATION
# # Data Science & Business Analytics Intern
# # Intern Name:M.K.Sanjana

# %% [markdown]
# ## Task 3:Task Description:Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\sanjana\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dataset =  pd.read_csv("SampleSuperstore.csv")

# %%
dataset.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
dataset.nunique(axis=1)
# Out:
# 0       13
# 1       13
# 2       13
# 3       13
# 4       13
#         ..
# 9989    13
# 9990    13
# 9991    13
# 9992    13
# 9993    13
# Length: 9994, dtype: int64

# %%
dataset.nunique(axis=0)
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, 
            cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x="Segment",y="Profit",data=dataset,kind='box',ci=95)

# %%
sns.catplot(x="Ship Mode",y="Profit",data=dataset,kind='bar',ci=None)

# %%
order = dataset.groupby(["State"])["Profit"].mean().sort_values().index
sns.catplot(y="State",x="Profit",data=dataset,kind='bar',ci=None,height=20,order=order)

# %%
sns.catplot(x="Category",y="Profit",data=df,kind="bar",ci=None)

# %%
sns.catplot(x="Category",y="Profit",data=df,kind='bar',ci=None,col="Region")

# %%
plt.subplots(figsize=(8,10))
order=df.groupby(['State'])["State"].count().sort_values().index
sns.countplot(y='State',data=df,order=order)
# Out:
# <AxesSubplot:xlabel='count', ylabel='State'>

# %% [markdown]
# #### States like Wyoming, North Dakota and West Virginia have no sales at all. Hence, these states need to be checked.
# #### States like California, New York and Texas have many coustomers. Hence these states can be concentrated upon to generate more profit
